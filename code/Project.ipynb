# %%
data_loc<-'/Users/Alexis/Documents/Spring2020/nonparametrics/data/Homicides.csv'
#data_loc<-'/Users/aporter1350/Documents/Courses/Spring2020/nonparametrics/data/Homicides.csv'
homocides<-read.csv(data_loc)

# %%
head(homocides)
# Out:
#   ID    Case.Number Date                   Block                  IUCR
# 1  2174 HJ374672    05/20/2003 03:15:00 AM 015XX N LASALLE ST     110
# 2   983 G446123     07/29/2001 10:15:00 AM 011XX N LASALLE ST     110
# 3 24378 JC113580    01/11/2019 10:30:00 PM 000XX E IDA B WELLS DR 110
# 4 24561 JC281195    05/27/2019 11:42:00 PM 085XX S CICERO AVE     110
# 5 24562 JC281250    05/28/2019 12:25:00 AM 018XX N MONTICELLO AVE 110
# 6 24563 JC281514    05/28/2019 09:25:00 AM 012XX N MASON AVE      110
#   Primary.Type Description         Location.Description Arrest Domestic ⋯ Ward
# 1 HOMICIDE     FIRST DEGREE MURDER APARTMENT            true   true     ⋯ NA
# 2 HOMICIDE     FIRST DEGREE MURDER ALLEY                true   false    ⋯ NA
# 3 HOMICIDE     FIRST DEGREE MURDER STREET               true   false    ⋯  4
# 4 HOMICIDE     FIRST DEGREE MURDER PARKING LOT          true   false    ⋯ 18
# 5 HOMICIDE     FIRST DEGREE MURDER PARK PROPERTY        true   false    ⋯  1
# ...

# %%
plot(density(homocides$Year, bw="SJ"), xlab='Homocide rates per year')
# Out:
# Error in density.default(homocides$Location.Description, bw = "SJ"): argument 'x' must be numeric
# Traceback:
#
# 1. plot(density(homocides$Location.Description, bw = "SJ"), xlab = "Homocide rates per year")
# 2. density(homocides$Location.Description, bw = "SJ")
# 3. density.default(homocides$Location.Description, bw = "SJ")
# 4. stop("argument 'x' must be numeric")
# Plot with title “density.default(x = homocides$Year, bw = "SJ")”

# %%
library('sm')

sm.regression(x=motor$time, y=motor$accel, poly.index=0, method='cv', ngrid=100)
